# %% [markdown]
# # Architecture Walkthrough
#
# **Status: not started.** This notebook is a placeholder — see the repository README's Notebooks section and `docs/architecture.md` for what it's meant to cover once there's a trained checkpoint / real experiment results to work with. Filling it in is blocked on Phase 1 (architecture validation) producing a checkpoint.

# %%
from ada import ADAConfig, ADAModel

config = ADAConfig.from_yaml("../configs/ada_nano.yaml")
print(config)
